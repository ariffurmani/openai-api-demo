# %%
# Install the required packages(required only once)
# !pip install openai python-dotenv -q

# %%
import textwrap
# Loading the keys

import os
from dotenv import load_dotenv

import textwrap

def prettyPrint(*args):
    text = " ".join(str(arg) for arg in args)
    try:
        print(textwrap.fill(text, width=80))
    except Exception as e:
        print(text)

# Load env file from the mentioned directory
load_dotenv('/home/furmani-arif/Documents/global-properties.env')

#fetch the openai api key fom the loaded env file
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError(
        "OPENAI_API_KEY not found! "
        "Make sure you have a .env file with OPENAI_API_KEY"
    )

prettyPrint("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
# Load the OpenAI client
from openai import OpenAI

client = OpenAI(api_key = api_key)
prettyPrint("OpenAI client is ready")
# Out:
# OpenAI client is ready

# %%
resp = client.responses.create(
    model="gpt-5-nano",
    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_text",
                    "text": "What's in this image?"
                },
                {
                    "type": "input_image",
                    "image_url": "https://www.animesenpai.net/wp-content/uploads/2023/12/sef-min.png.webp"
                }
            ]
        }
    ]
)

prettyPrint("\n=== Vision Analysis (Responses API) ===")
prettyPrint(resp.output_text)

prettyPrint("\nInput tokens:", resp.usage.input_tokens)
prettyPrint("Output tokens:", resp.usage.output_tokens)
prettyPrint("Total tokens:", resp.usage.total_tokens)
# Out:
#  === Vision Analysis (Responses API) ===
# - An anime-style, muscular demon/monster with pale blue-gray skin. - Its chest
# shows rib-like grooves, and it has a long tail ending in a curved blade. - It
# has sharp, claw-like hands and some blade-like protrusions on its arms; the
# background is smoky and dark.
#  Input tokens: 802
# Output tokens: 1018
# Total tokens: 1820

# %%
import base64

prompt = "An old strict dog tutor teaching AI in a bright classroom, anime style"

resp = client.images.generate(
    model="gpt-image-1",
    prompt=prompt,
    size="1024x1024",
    quality="medium",
    n=1
)

# image_url = resp.data[0].url
# print("Image URL:", image_url)
prettyPrint("Image Generation Response:", resp)
prettyPrint("\nInput tokens:", resp.usage.input_tokens)
prettyPrint("Output tokens:", resp.usage.output_tokens)
prettyPrint("Total tokens:", resp.usage.total_tokens)

image_base64 = resp.data[0].b64_json

with open("image.png", "wb") as f:
    f.write(base64.b64decode(image_base64))
# Out:
# Image Generation Response: ImagesResponse(created=1780552073,
# background='opaque', data=[Image(b64_json='iVBORw0KGgoAAAANSUhEUgAABAAAAAQACAIAA
# ADwf7zUAABhIWNhQlgAAGEhanVtYgAAAB5qdW1kYzJwYQARABCAAACqADibcQNjMnBhAAAAYPtqdW1iA
# AAAR2p1bWRjMm1hABEAEIAAAKoAOJtxA3VybjpjMnBhOjQ2YTA5YjI4LTAxNzMtNDk5My05OTRiLWY4Y
# WNkNTI5NjI5YQAAABfEanVtYgAAAClqdW1kYzJhcwARABCAAACqADibcQNjMnBhLmFzc2VydGlvbnMAA
# AAJ0Wp1bWIAAAA7anVtZEDLDDK7ikidpwsq1vR/Q2kTYzJwYS5pY29uAAAAABhjMnNopXKsm7QLpZTeM
# 95PVX32awAAABdiZmRiAGltYWdlL3N2Zyt4bWwAAAAJd2JpZGI8c3ZnIHdpZHRoPSI3MTYiIGhlaWdod
# D0iNzE2IiB2aWV3Qm94PSIwIDAgNzE2IDcxNiIgZmlsbD0ibm9uZSIgeG1sbnM9Imh0dHA6Ly93d3cud
# zMub3JnLzIwMDAvc3ZnIj4KPHBhdGggZD0iTTUwOC43NDkgMzE3LjM5OUM1MTYuNzc3IDI4Ny4zMTQgN
# TA4Ljk5MSAyNTMuODg0IDQ4NS4zODkgMjMwLjI4MkM0NjEuNzg4IDIwNi42ODEgNDI4LjM2IDE5OC44O
# TUgMzk4LjI3MyAyMDYuOTIzQzM3Ni4yMzEgMTg0LjkyOCAzNDMuMzkgMTc0Ljk1NiAzMTEuMTQ4IDE4M
# y41OTZDMjc4LjkwNiAxOTIuMjM0IDI1NS40NSAyMTcuMjkyIDI0Ny4zNiAyNDcuMzYxQzIxNy4yOTEgM
# ...
